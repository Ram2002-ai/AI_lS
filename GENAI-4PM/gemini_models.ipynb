# %%
import sys
# !{sys.executable} -m pip install google-generativeai
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\USER\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
import google.generativeai as genai
# model=genai.GenerativeModel('gemini-3-flash-preview')
model=genai.GenerativeModel('models/gemini-2.0-flash')

# %%
response=model.generate_content('What is Gemini 3 Flash?')
response.text
# Out:
# 'As of late 2024, there is **no official model called Gemini 3 Flash.**\n\nIt is highly likely that you are referring to **Gemini 1.5 Flash**, which is currently one of Google’s most popular and widely used AI models.\n\nHere is a breakdown of what **Gemini 1.5 Flash** is and why it is significant:\n\n### 1. What is Gemini 1.5 Flash?\nGemini 1.5 Flash is a "lightweight" model released by Google DeepMind. It was designed to sit between the smaller Gemini Nano (on-device) and the more powerful Gemini 1.5 Pro. It is optimized for **speed and efficiency** rather than raw power.\n\n### 2. Key Features\n*   **High Speed/Low Latency:** It is designed for applications where a quick response is more important than deep reasoning (e.g., chatbots, live customer service).\n*   **Massive Context Window:** Like the Pro version, it features a **1-million-token context window**. This allows it to process massive amounts of data at once, such as an hour of video, thousands of lines of code, or long d
# ...

# %%
response=model.generate_content('What is Gemini 3 Flash?')
response.text
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\USER\anaconda3\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
# ...

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import Markdown, display

def to_markdown(text):
    text=text.replace('.',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _:True))

# %%
for m in genai.list_models():
   if 'generateContent' in m.supported_generation_methods:
      print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# ...

# %%
model=genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
from IPython.display import Markdown

response = model.generate_content(
    'give me a list of 5 features of Gemini 1.5 Flash'
)

Markdown(response.text)
# Out:
# Here are 5 key features of **Gemini 1.5 Flash**, Google’s lightweight, high-speed AI model:
#
# ### 1. Massive 1-Million-Token Context Window
# Despite being a "smaller" model, Gemini 1.5 Flash features a context window of up to **1 million tokens**. This allows it to process massive amounts of information in a single prompt, such as an hour of video, 11 hours of audio, codebases with over 30,000 lines, or documents over 700,000 words.
#
# ### 2. Optimized for Speed and Low Latency
# The "Flash" name refers to its primary design goal: **speed**. It is significantly faster than Gemini 1.5 Pro. This makes it ideal for real-time applications like customer service chatbots, live transcription, and any interface where a near-instant response is required.
#
# ### 3. Native Multimodality
# ...

# %%
for chunk in response:
    print(chunk.text)
# Out:
# Here are 5 key features of **Gemini 1.5 Flash**, Google’s lightweight, high-speed AI model:
#
# ### 1. Massive 1-Million-Token Context Window
# Despite being a "smaller" model, Gemini 1.5 Flash features a context window of up to **1 million tokens**. This allows it to process massive amounts of information in a single prompt, such as an hour of video, 11 hours of audio, codebases with over 30,000 lines, or documents over 700,000 words.
#
# ### 2. Optimized for Speed and Low Latency
# The "Flash" name refers to its primary design goal: **speed**. It is significantly faster than Gemini 1.5 Pro. This makes it ideal for real-time applications like customer service chatbots, live transcription, and any interface where a near-instant response is required.
#
# ### 3. Native Multimodality
# ...

# %% [markdown]
# # Image to Text Generation
# ### Multimodel

# %%
# Multimodel

# %%
import PIL.Image
img=PIL.Image.open("E:\Photos\gulshan.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=963x1280>

# %%
model=genai.GenerativeModel('models/gemini-3.1-flash-lite')

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import Markdown, display

def to_markdown(text):
    text=text.replace('.',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _:True))

# %%
response=model.generate_content(img)

# %%
to_markdown(response.text)
# Out:
# > Based on the image provided, there are a few features that warrant professional evaluation *
# >
# > The dark, pigmented area on the bridge of the nose and the slightly pigmented patches on the skin near the inner corners of the eyes are features that should be examined by a healthcare professional, such as a dermatologist *
# >
# > While these types of skin markings can often be benign (such as post-inflammatory hyperpigmentation or other harmless conditions), it is important to have a doctor look at them in person to:
# > *   Rule out any underlying medical conditions *
# > *   Distinguish between benign spots and conditions that may require treatment *
# > *   Monitor for any changes in color, size, or shape *
# >
# > **When to see a doctor promptly:**
# > You should consult a doctor if you notice any of the following "ABCDE" warning signs in these or any other skin spots:
# > *   **Asymmetry:** One half of the spot does not match the other *
# ...

# %%
response=model.generate_content(['write a script for 5 sec instgram shoot to gain good view', img],stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > To get high views on Instagram in 5 seconds, you need **fast pacing, a strong hook, and a "loopable" transition ***
# >
# > Since your photo looks like a clean, professional portrait, here are three high-engagement concepts:
# >
# > ### Option 1: The "Glow Up" / Transformation (Trending & Engaging)
# > *This works because people love seeing personality changes **
# > *   **0-2 sec:** Start with a "serious" face, looking directly at the camera (like your photo) *
# > *   **2-3 sec:** A quick transition (snap your fingers or cover the lens) *
# > *   **3-5 sec:** Cut to you in a completely different outfit, smiling, or doing something fun/casual *
# > *   **Text Overlay:** "POV: You finally stopped being shy *"
# > *   **Music:** A trending upbeat song with a clear "beat drop" at 2 seconds *
# >
# > ### Option 2: The "Personality Loop" (Best for engagement)
# > *This is great for the algorithm because people will watch it multiple times to catch the details **
# ...

# %%
model=genai.GenerativeModel('models/gemini-3.1-flash-lite')
chat=model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-3.1-flash-lite',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )
