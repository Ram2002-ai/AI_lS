# %%
# !pip install -q -U google-genarativeai
# !pip install ddgs
# !pip install litellm
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement google-genarativeai (from versions: none)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\USER\anaconda3\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for google-genarativeai
# Requirement already satisfied: ddgs in C:\Users\USER\anaconda3\Lib\site-packages (9.14.4)
# Requirement already satisfied: click>=8.1.8 in C:\Users\USER\anaconda3\Lib\site-packages (from ddgs) (8.1.8)
# Requirement already satisfied: primp>=1.2.3 in C:\Users\USER\anaconda3\Lib\site-packages (from ddgs) (1.3.1)
# Requirement already satisfied: lxml>=4.9.4 in C:\Users\USER\anaconda3\Lib\site-packages (from ddgs) (5.3.0)
# Requirement already satisfied: httpx>=0.28.1 in C:\Users\USER\anaconda3\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: colorama in C:\Users\USER\anaconda3\Lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\USER\anaconda3\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.10.0)
# Requirement already satisfied: certifi in C:\Users\USER\anaconda3\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\USER\anaconda3\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in C:\Users\USER\anaconda3\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\USER\anaconda3\Lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in C:\Users\USER\anaconda3\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in C:\Users\USER\anaconda3\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.2.0)
# Requirement already satisfied: socksio==1.* in C:\Users\USER\anaconda3\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\USER\anaconda3\Lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\USER\anaconda3\python.exe -m pip install --upgrade pip
# Requirement already satisfied: litellm in C:\Users\USER\anaconda3\Lib\site-packages (1.87.1)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.14.0)
# Requirement already satisfied: httpx<1.0,>=0.28.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.28.1)
# Requirement already satisfied: openai<3.0.0,>=2.20.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (2.32.0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (1.1.0)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.12.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (8.7.0)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.22.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (8.1.8)
# Requirement already satisfied: jinja2<4.0,>=3.1.6 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (3.1.6)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (3.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (2.12.4)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (4.25.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (1.22.0)
# Requirement already satisfied: colorama in C:\Users\USER\anaconda3\Lib\site-packages (from click<9.0,>=8.0.0->litellm) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (4.10.0)
# Requirement already satisfied: certifi in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (1.0.9)
# Requirement already satisfied: idna in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (2.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\USER\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in C:\Users\USER\anaconda3\Lib\site-packages (from importlib-metadata<9.0,>=8.0.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from jinja2<4.0,>=3.1.6->litellm) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\USER\anaconda3\Lib\site-packages (from jsonschema<5.0,>=4.0.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\USER\anaconda3\Lib\site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\USER\anaconda3\Lib\site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.28.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (0.14.0)
# Requirement already satisfied: sniffio in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (1.3.0)
# Requirement already satisfied: tqdm>4 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\USER\anaconda3\Lib\site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2026.5.9)
# Requirement already satisfied: requests>=2.26.0 in C:\Users\USER\anaconda3\Lib\site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2.32.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\USER\anaconda3\Lib\site-packages (from tokenizers<1.0,>=0.21.0->litellm) (1.6.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.3.2)
# Requirement already satisfied: packaging>=20.9 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (6.0.3)
# Requirement already satisfied: typer in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.17.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\USER\anaconda3\Lib\site-packages (from requests>=2.26.0->tiktoken<1.0,>=0.8.0->litellm) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\USER\anaconda3\Lib\site-packages (from requests>=2.26.0->tiktoken<1.0,>=0.8.0->litellm) (2.6.3)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.1.2)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\USER\anaconda3\python.exe -m pip install --upgrade pip

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in C:\Users\USER\anaconda3\Lib\site-packages (6.9.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (4.10.0)
# Requirement already satisfied: audioop-lts<1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.136.3)
# Requirement already satisfied: ffmpy in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.3.0)
# Requirement already satisfied: groovy~=0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (1.6.0)
# Requirement already satisfied: jinja2<4.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.4.4)
# Requirement already satisfied: orjson~=3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.12.4)
# Requirement already satisfied: pydub in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.17.4)
# Requirement already satisfied: typing-extensions~=4.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.30.0)
# Requirement already satisfied: fsspec in C:\Users\USER\anaconda3\Lib\site-packages (from gradio-client==2.3.0->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\USER\anaconda3\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (2.10)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\USER\anaconda3\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\USER\anaconda3\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\USER\anaconda3\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\USER\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.3.2)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\USER\anaconda3\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\USER\anaconda3\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.5)
# Requirement already satisfied: click>=8.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: colorama in C:\Users\USER\anaconda3\Lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in C:\Users\USER\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\USER\anaconda3\python.exe -m pip install --upgrade pip

# %%
# !pip install smolagents
# Out:
# Requirement already satisfied: smolagents in C:\Users\USER\anaconda3\Lib\site-packages (1.26.0)
# Requirement already satisfied: huggingface-hub>=0.31.2 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (1.6.0)
# Requirement already satisfied: requests>=2.32.3 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (14.2.0)
# Requirement already satisfied: jinja2>=3.1.4 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (11.3.0)
# Requirement already satisfied: python-dotenv in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (1.1.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (4.67.1)
# Requirement already satisfied: typer in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (0.17.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (4.10.0)
# Requirement already satisfied: certifi in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (1.0.9)
# Requirement already satisfied: idna in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (2.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\USER\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from jinja2>=3.1.4->smolagents) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\USER\anaconda3\Lib\site-packages (from requests>=2.32.3->smolagents) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\USER\anaconda3\Lib\site-packages (from requests>=2.32.3->smolagents) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=13.9.4->smolagents) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: colorama in C:\Users\USER\anaconda3\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.31.2->smolagents) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\USER\anaconda3\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer->huggingface-hub>=0.31.2->smolagents) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer->huggingface-hub>=0.31.2->smolagents) (1.5.4)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\USER\anaconda3\python.exe -m pip install --upgrade pip

# %%
# python -m pip install --upgrade pip
# !pip install smolagents litellm gradio google-generativeai duckduckgo-search
# Out:
# Requirement already satisfied: smolagents in C:\Users\USER\anaconda3\Lib\site-packages (1.26.0)
# Requirement already satisfied: litellm in C:\Users\USER\anaconda3\Lib\site-packages (1.87.1)
# Requirement already satisfied: gradio in C:\Users\USER\anaconda3\Lib\site-packages (6.9.0)
# Requirement already satisfied: google-generativeai in C:\Users\USER\anaconda3\Lib\site-packages (0.8.6)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: huggingface-hub>=0.31.2 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (1.6.0)
# Requirement already satisfied: requests>=2.32.3 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (14.2.0)
# Requirement already satisfied: jinja2>=3.1.4 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (11.3.0)
# Requirement already satisfied: python-dotenv in C:\Users\USER\anaconda3\Lib\site-packages (from smolagents) (1.1.0)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.14.0)
# Requirement already satisfied: httpx<1.0,>=0.28.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.28.1)
# Requirement already satisfied: openai<3.0.0,>=2.20.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (2.32.0)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.12.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (8.7.0)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (0.22.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (8.1.8)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (3.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (2.12.4)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from litellm) (4.25.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\USER\anaconda3\Lib\site-packages (from aiohttp<4.0,>=3.10->litellm) (1.22.0)
# Requirement already satisfied: colorama in C:\Users\USER\anaconda3\Lib\site-packages (from click<9.0,>=8.0.0->litellm) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (4.10.0)
# Requirement already satisfied: certifi in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (1.0.9)
# Requirement already satisfied: idna in C:\Users\USER\anaconda3\Lib\site-packages (from httpx<1.0,>=0.28.0->litellm) (2.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\USER\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in C:\Users\USER\anaconda3\Lib\site-packages (from importlib-metadata<9.0,>=8.0.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from jinja2>=3.1.4->smolagents) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\USER\anaconda3\Lib\site-packages (from jsonschema<5.0,>=4.0.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\USER\anaconda3\Lib\site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\USER\anaconda3\Lib\site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.28.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (0.14.0)
# Requirement already satisfied: sniffio in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (1.3.0)
# Requirement already satisfied: tqdm>4 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\USER\anaconda3\Lib\site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\USER\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\USER\anaconda3\Lib\site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2026.5.9)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (1.3.2)
# Requirement already satisfied: packaging>=20.9 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: typer in C:\Users\USER\anaconda3\Lib\site-packages (from huggingface-hub>=0.31.2->smolagents) (0.17.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: audioop-lts<1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.136.3)
# Requirement already satisfied: ffmpy in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.3.0)
# Requirement already satisfied: groovy~=0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.4.4)
# Requirement already satisfied: orjson~=3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (3.11.7)
# Requirement already satisfied: pandas<4.0,>=1.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pydub in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: uvicorn>=0.14.0 in C:\Users\USER\anaconda3\Lib\site-packages (from gradio) (0.30.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\USER\anaconda3\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\USER\anaconda3\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\USER\anaconda3\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.3)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from typer->huggingface-hub>=0.31.2->smolagents) (1.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in C:\Users\USER\anaconda3\Lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in C:\Users\USER\anaconda3\Lib\site-packages (from google-generativeai) (2.30.3)
# Requirement already satisfied: google-api-python-client in C:\Users\USER\anaconda3\Lib\site-packages (from google-generativeai) (2.196.0)
# Requirement already satisfied: google-auth>=2.15.0 in C:\Users\USER\anaconda3\Lib\site-packages (from google-generativeai) (2.49.2)
# Requirement already satisfied: protobuf in C:\Users\USER\anaconda3\Lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in C:\Users\USER\anaconda3\Lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in C:\Users\USER\anaconda3\Lib\site-packages (from google-api-core->google-generativeai) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\USER\anaconda3\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in C:\Users\USER\anaconda3\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\USER\anaconda3\Lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\USER\anaconda3\Lib\site-packages (from google-auth>=2.15.0->google-generativeai) (46.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\USER\anaconda3\Lib\site-packages (from requests>=2.32.3->smolagents) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\USER\anaconda3\Lib\site-packages (from requests>=2.32.3->smolagents) (2.6.3)
# Requirement already satisfied: primp>=0.15.0 in C:\Users\USER\anaconda3\Lib\site-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in C:\Users\USER\anaconda3\Lib\site-packages (from duckduckgo-search) (5.3.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\USER\anaconda3\Lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\USER\anaconda3\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\USER\anaconda3\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\USER\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=13.9.4->smolagents) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\USER\anaconda3\Lib\site-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in C:\Users\USER\anaconda3\Lib\site-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in C:\Users\USER\anaconda3\Lib\site-packages (from google-api-python-client->google-generativeai) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in C:\Users\USER\anaconda3\Lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in C:\Users\USER\anaconda3\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.2)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Installing collected packages: duckduckgo-search
# Successfully installed duckduckgo-search-8.1.1
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\USER\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\USER\anaconda3\python.exe -m pip install --upgrade pip

# %%
pip show smolagents litellm gradio google-generativeai duckduckgo-search
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: duckduckgo-search, google-generativeai, gradio, litellm, smolagents

# %%
import os
import litellm
import gradio as gr
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel
import google.generativeai as genai
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11700\3970850956.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
from smolagents import CodeAgent, LiteLLMModel
from smolagents import DuckDuckGoSearchTool

model = LiteLLMModel(
    model_id="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY")
)

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
    additional_authorized_imports=["pandas", "numpy", "sklearn",'json']

)

# %%
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
import os
os.environ["LITELLM_LOG"] = "DEBUG"

# %%
import os
from smolagents import LiteLLMModel

model = LiteLLMModel(
    model_id="gemini/gemini-2.5-flash",
    api_key=os.environ["GOOGLE_API_KEY"]
)

# %%
ml_code_agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    additional_authorized_imports=["pandas", "numpy", "sklearn",'json'],
    model=model
)

# %%
# Function to Generate ML Code Step-by-Step
def generate_ml_code(prompt):
    full_prompt = """
    You are an AI assistant helping with machine learning code. 
    Complete ALL 7 steps in a structured manner.

    1. **Load the Diabetes dataset** using sklearn.
    2. **Split the data** (75% train / 25% test).
    3. **Train a linear regression model**.
    4. **Find the best 3-feature combination** (lowest RMSE).
    5. **Apply feature engineering** if needed.
    6. **List the top 5 models based on RMSE**.
    7. **Output the results in a structured table**.

    Ensure that you return:
    - The Python code for each step.
    - The RMSE values of the models.
    - The final selected feature set.
    """
    try:
        response = ml_code_agent.run(full_prompt)
        return response
    except Exception as e:
        return f"Error: {str(e)}"

# %%
import gradio as gr

iface=gr.Interface(fn=generate_ml_code, inputs="text", outputs="text", title="ML Code Generator")
iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ You are an AI assistant helping with machine learning code.                                                     │
# │     Complete ALL 7 steps in a structured manner.                                                                │
# │                                                                                                                 │
# │     1. **Load the Diabetes dataset** using sklearn.                                                             │
# │     2. **Split the data** (75% train / 25% test).                                                               │
# │     3. **Train a linear regression model**.                                                                     │
# │     4. **Find the best 3-feature combination** (lowest RMSE).                                                   │
# │     5. **Apply feature engineering** if needed.                                                                 │
# │     6. **List the top 5 models based on RMSE**.                                                                 │
# │     7. **Output the results in a structured table**.                                                            │
# │                                                                                                                 │
# │     Ensure that you return:                                                                                     │
# │     - The Python code for each step.                                                                            │
# │     - The RMSE values of the models.                                                                            │
# │     - The final selected feature set.                                                                           │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.5-flash ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   from sklearn.datasets import load_diabetes
#   from sklearn.model_selection import train_test_split
#   import pandas as pd
#   import numpy as np
#
#   # Step 1: Load the Diabetes dataset
#   diabetes = load_diabetes()
#   X = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
#   y = diabetes.target
#
#   print("Diabetes dataset loaded. Features shape:", X.shape, "Target shape:", y.shape)
#
#   # Step 2: Split the data (75% train / 25% test)
#   X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
#   print("Data split into training (75%) and testing (25%).")
#   print("X_train shape:", X_train.shape, "X_test shape:", X_test.shape)
#   print("y_train shape:", y_train.shape, "y_test shape:", y_test.shape)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'from sklearn.datasets import load_diabetes' due to: InterpreterError: Import from
# sklearn.datasets is not allowed. Authorized imports are: ['json', 'pandas', 'queue', 'unicodedata', 'collections',
# 'itertools', 'datetime', 'stat', 'numpy', 'sklearn', 're', 'statistics', 'time', 'random', 'math']
# [Step 1: Duration 6.24 seconds| Input tokens: 2,383 | Output tokens: 953]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import sklearn
#   import pandas as pd
#   import numpy as np
#
#   # Step 1: Load the Diabetes dataset
#   diabetes = sklearn.datasets.load_diabetes()
#   X = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
#   y = diabetes.target
#
#   print("Diabetes dataset loaded. Features shape:", X.shape, "Target shape:", y.shape)
#
#   # Step 2: Split the data (75% train / 25% test)
#   X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.25,
#   random_state=42)
#
#   print("Data split into training (75%) and testing (25%).")
#   print("X_train shape:", X_train.shape, "X_test shape:", X_test.shape)
#   print("y_train shape:", y_train.shape, "y_test shape:", y_test.shape)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'diabetes = sklearn.datasets.load_diabetes()' due to: InterpreterError: Forbidden
# access to module: sklearn.datasets
# [Step 2: Duration 16.28 seconds| Input tokens: 5,486 | Output tokens: 1,431]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# Error in generating model output:
# litellm.ServiceUnavailableError: GeminiException - {
#   "error": {
#     "code": 503,
#     "message": "This model is currently experiencing high demand. Spikes in demand are usually temporary. Please
# try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
# [Step 3: Duration 11.41 seconds]
